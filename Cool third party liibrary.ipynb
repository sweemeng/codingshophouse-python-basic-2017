# %% [markdown]
# As you work around, you will find some tools is very useful to have. Here's a few

# %% [markdown]
# ## iPython
# More often than not you need to test idea in your code. That's why python installation comes with a shell. The default shell is ok. But there is a better commonly used shell. We need to switch the context to ipython shell

# %% [markdown]
# ## Requests
# It is a simple http client, for you to work/test on website/http API.

# %%
import requests

r = requests.get("https://google.com")
print(r.status_code)
print(r.content)
# Out:
# 200
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world\'s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you\'re looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script>(function(){window.google={kEI:\'WK18WMHALsTkvgTo4pWoBg\',kEXPI:\'750722,1351903,1352273,1352298,1352352,1352443,3700251,3700347,4029815,4032677,4038012,4043492,4045841,4048347,4062666,4065786,4066195,4068550,4069839,4069841,4070141,4071842,4072602,4072774,4073405,4073728,4073958,4074955,4075770,4075963,4076096,4076316,4076930,4076999,4078430,4078438,4078763,4079081,4079105,4079441,4079896,4080167,4081039,4081487,4082618,4083030,4083476,4083496,4084343,4084956,4085628,4085685,4086011,4086788,4086797,4086810,4087708,4089003,4089106,4089538,4089645,4090209,4090657,4090806,4090850,4090894,4091060,4091302,4092469,4092705,4092889,4092932,8300096,8300272,8300484,8504111,8507381,8507420,8507861,8508043,8508207,8508624,8508911,8509066,8509596,10200084,13500021,13500024\',authuser:0,kscs:\'c9c918f0_24\'};google.kHL=\'en\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b};google.https=function(){return"https:"==window.location.protocol};google.ml=function(){return null};google.wl=function(a,b){try{google.ml(Error(a),!1,b)}catch(c){}};google.time=function(){return(new Date).getTime()};google.log=function(a,b,c,d,g){a=google.logUrl(a,b,c,d,g);if(""!=a){b=new Image;var e=google.lc,f=google.li;e[f]=b;b.onerror=b.onload=b.onabort=function(){delete e[f]};window.google&&window.google.vel&&window.google.vel.lu&&window.google.vel.lu(a);b.src=a;google.li=f+1}};google.logUrl=function(a,b,c,d,g){var e="",f=google.ls||"";c||-1!=b.search("&ei=")||(e="&ei="+google.getEI(d),-1==b.search("&lei=")&&(d=google.getLEI(d))&&(e+="&lei="+d));a=c||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+e+f+"&zx="+google.time();/^http:/i.test(a)&&google.https()&&(google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a};google.y={};google.x=function(a,b){google.y[a.id]=[a,b];return!1};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};}).call(this);var a=window.location,b=a.href.indexOf("#");if(0<=b){var c=a.href.substring(b+1);/(^|&)q=/.test(c)&&-1==c.indexOf("#")&&a.replace("/search?"+c.replace(/(^|&)fp=[^&]*/g,"")+"&cad=h")};</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}\n</style><style>body,td,a,p,.h{font-family:arial,sans-serif}body{margin:0;overflow-y:scroll}#gog{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20px}.h{color:#36c}.q{color:#00c}.ts td{padding:0}.ts{border-collapse:collapse}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px arial,sans-serif}.gsfs{font:17px arial,sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0 4px;margin-left:4px}input{font-family:inherit}a.gb1,a.gb2,a.gb3,a.gb4{color:#11c !important}body{background:#fff;color:black}a{color:#11c;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{color:#36c}a:visited{color: ...

# %% [markdown]
# Let's say you have content that uses json

# %%
r = requests.get("https://httpbin.org/get")
print(r.status_code)
print(r.content)
print(r.json())
# Out:
# 200
# b'{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.12.4"\n  }, \n  "origin": "210.195.155.153", \n  "url": "https://httpbin.org/get"\n}\n'
# {'origin': '210.195.155.153', 'args': {}, 'headers': {'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.12.4', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*'}, 'url': 'https://httpbin.org/get'}

# %% [markdown]
# You can also post at request

# %%
r = requests.post("https://httpbin.org/post", data={"a":1, "b":2})
print(r.status_code)
print(r.content)
# Out:
# 200
# b'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "a": "1", \n    "b": "2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "7", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.12.4"\n  }, \n  "json": null, \n  "origin": "210.195.155.153", \n  "url": "https://httpbin.org/post"\n}\n'

# %% [markdown]
# If you scrape website something you need to mess with headers. You can do that too

# %%
r = requests.get("https://httpbin.org/headers", headers={"User-Agent":"codingshophouse/1.0"})
print(r.status_code)
print(r.content)
# Out:
# 200
# b'{\n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "codingshophouse/1.0"\n  }\n}\n'

# %% [markdown]
# Sometime you will fetch html. Then you will use library like BeautifulSoup to process the data

# %% [markdown]
# ## Matplotlib
# It is a standard plotting library, very powerful, but not the easiest library to use.

# %%
import matplotlib.pyplot as plt

line, = plt.plot(range(10), range(10))
plt.title("Simple Straight line")
plt.show()

# %% [markdown]
# ## Pandas
# I will show some tools that can do some data work to expose a little on data science. Because python can be cool at this.

# %%
import pandas
pd = pandas.read_csv("16-bacaanipu2014-2015.csv")
pd
# Out:
#             Tarikh   Waktu               Negeri                       Kawasan  \
# 0       25/11/2014  7:00AM              Sarawak                       Limbang
# 1       25/11/2014  7:00AM              Sarawak                     Samarahan
# 2       25/11/2014  7:00AM              Sarawak                      Sri Aman
# 3       25/11/2014  7:00AM              Sarawak                         Kapit
# 4       25/11/2014  7:00AM                Sabah                 Kota Kinabalu
# 5       25/11/2014  7:00AM                Sabah                         Tawau
# 6       25/11/2014  7:00AM                Sabah                      Keningau
# 7       25/11/2014  7:00AM                Sabah                      Sandakan
# 8       25/11/2014  8:00AM               Perlis                        Kangar
# 9       25/11/2014  8:00AM                Kedah                      Langkawi
# 10      25/11/2014  8:00AM                Kedah                    Alor Setar
# 11      25/11/2014  8:00AM                Kedah       Bakar Arang, Sg. Petani
# 12      25/11/2014  8:00AM         Pulau Pinang                           USM
# 13      25/11/2014  8:00AM         Pulau Pinang                         Perai
# 14      25/11/2014  8:00AM         Pulau Pinang        Seberang Jaya 2, Perai
# 15      25/11/2014  8:00AM                Perak             Jalan Tasek, Ipoh
# 16      25/11/2014  8:00AM                Perak         S K Jalan Pegoh, Ipoh
# 17      25/11/2014  8:00AM                Perak        Kg. Air Putih, Taiping
# 18      25/11/2014  8:00AM                Perak                  Seri Manjung
# 19      25/11/2014  8:00AM                Perak                 Tanjung Malim
# 20      25/11/2014  8:00AM             Selangor              Pelabuhan Kelang
# 21      25/11/2014  8:00AM             Selangor                 Petaling Jaya
# 22      25/11/2014  8:00AM             Selangor                       Banting
# 23      25/11/2014  8:00AM             Selangor                     Shah Alam
# 24      25/11/2014  8:00AM             Selangor                Kuala Selangor
# 25      25/11/2014  8:00AM  Wilayah Persekutuan        Batu Muda,Kuala Lumpur
# 26      25/11/2014  8:00AM  Wilayah Persekutuan           Cheras,Kuala Lumpur
# 27      25/11/2014  8:00AM  Wilayah Persekutuan                     Putrajaya
# 28      25/11/2014  8:00AM  Wilayah Persekutuan                        Labuan
# 29      25/11/2014  8:00AM      Negeri Sembilan                         Nilai
# ...            ...     ...                  ...                           ...
# 245722  10/06/2015  1:00PM      Negeri Sembilan                      Seremban
# 245723  10/06/2015  1:00PM      Negeri Sembilan                  Port Dickson
# 245724  10/06/2015  1:00PM               Melaka                  Bukit Rambai
# 245725  10/06/2015  1:00PM               Melaka              Bandaraya Melaka
# 245726  10/06/2015  1:00PM                Johor                  Pasir Gudang
# 245727  10/06/2015  1:00PM                Johor                   Larkin Lama
# 245728  10/06/2015  1:00PM                Johor                          Muar
# 245729  10/06/2015  1:00PM                Johor                   Kota Tinggi
# 245730  10/06/2015  1:00PM             Kelantan                  Tanah Merah
# 245731  10/06/2015  1:00PM             Kelantan  SMK Tanjung Chat, Kota Bharu
# 245732  10/06/2015  1:00PM           Terengganu                       Kemaman
# 245733  10/06/2015  1:00PM           Terengganu                          Paka
# 245734  10/06/2015  1:00PM           Terengganu              Kuala Terengganu
# 245735  10/06/2015  1:00PM               Pahang                      Jerantut
# 245736  10/06/2015  1:00PM               Pahang       Indera Mahkota, Kuantan
# 245737  10/06/2015  1:00PM               Pahang           Balok Baru, Kuantan
# 245738  10/06/2015  1:00PM              Sarawak                       Kuching
# 245739  10/06/2015  1:00PM              Sarawak                          Sibu
# 245740  10/06/2015  1:00PM              Sarawak                       Bintulu
# 245741  10/06/2015  1:00PM              Sarawak                          Miri
# 245742  10/06/2015  1:00PM              Sarawak                      ILP Miri
# 245743  10/06/2015  1:00PM              Sarawak                       Sarikei
# 245744  10/06/2015  1:00PM              Sarawak                       Limbang
# 245745  10/06/2015  1:00PM              Sarawak                     Samarahan
# 245746  10/06/2015  1:00PM              Sarawak                      Sri Aman
# 245747  10/06/2015  1:00PM              Sarawak                         Kapit
# 245748  10/06/2015  1:00PM                Sabah                 Kota Kinabalu
# 245749  10/06/2015  1:00PM                Sabah                         Tawau
# 245750  10/06/2015  1:00PM                Sabah                      Keningau
# 245751  10/06/2015  1:00PM                Sabah                      Sandakan
#
#         API
# 0       27*
# 1       19*
# 2       30*
# 3       19*
# 4       46*
# 5       26*
# 6       34*
# 7       39*
# 8       20*
# 9       25*
# 10      36*
# 11      57*
# 12      51*
# 13      30*
# 14      51*
# 15      38*
# 16      26*
# 17      43*
# 18      27*
# 19      14*
# 20      40*
# 21      31*
# 22      36*
# 23      28*
# 24      19*
# 25      24*
# 26      34*
# 27      31*
# 28      17*
# 29      35*
# ...     ...
# 245722  47c
# 245723  36*
# 245724  47*
# 245725  57c
# 245726  51*
# 245727  29*
# 245728  36*
# 245729    #
# 245730  26*
# 245731  53*
# 245732  51*
# 245733  55*
# 245734  38*
# 245735  47*
# 245736  49c
# 245737  51*
# 245738  21*
# 245739  30*
# 245740  23*
# 245741  20*
# 245742  23*
# 245743  33*
# 245744  17*
# 245745  37*
# 245746  25*
# 245747  18*
# 245748    #
# 245749  28*
# 245750    #
# 245751  29*
#
# [245752 rows x 5 columns]

# %%
print(pd["Negeri"].value_counts())
# Out:
# Sarawak                47264
# Selangor               23630
# Perak                  23630
# Sabah                  18908
# Johor                  18904
# Wilayah Persekutuan    18904
# Pulau Pinang           14178
# Terengganu             14178
# Kedah                  14178
# Negeri Sembilan        14178
# Pahang                 14178
# Melaka                  9452
# Kelantan                9452
# Perlis                  4718
# Name: Negeri, dtype: int64

# %%
print(pd["API"])
# Out:
# 0         27*
# 1         19*
# 2         30*
# 3         19*
# 4         46*
# 5         26*
# 6         34*
# 7         39*
# 8         20*
# 9         25*
# 10        36*
# 11        57*
# 12        51*
# 13        30*
# 14        51*
# 15        38*
# 16        26*
# 17        43*
# 18        27*
# 19        14*
# 20        40*
# 21        31*
# 22        36*
# 23        28*
# 24        19*
# 25        24*
# 26        34*
# 27        31*
# 28        17*
# 29        35*
#          ...
# 245722    47c
# 245723    36*
# 245724    47*
# 245725    57c
# 245726    51*
# 245727    29*
# 245728    36*
# 245729      #
# 245730    26*
# 245731    53*
# 245732    51*
# 245733    55*
# 245734    38*
# 245735    47*
# 245736    49c
# 245737    51*
# 245738    21*
# 245739    30*
# 245740    23*
# 245741    20*
# 245742    23*
# 245743    33*
# 245744    17*
# 245745    37*
# 245746    25*
# 245747    18*
# 245748      #
# 245749    28*
# 245750      #
# 245751    29*
# Name: API, dtype: object

# %%
temp=pd[pd["Tarikh"]=="25/11/2014"]

# %%
temp
# Out:
#          Tarikh    Waktu               Negeri                       Kawasan  \
# 0    25/11/2014   7:00AM              Sarawak                       Limbang
# 1    25/11/2014   7:00AM              Sarawak                     Samarahan
# 2    25/11/2014   7:00AM              Sarawak                      Sri Aman
# 3    25/11/2014   7:00AM              Sarawak                         Kapit
# 4    25/11/2014   7:00AM                Sabah                 Kota Kinabalu
# 5    25/11/2014   7:00AM                Sabah                         Tawau
# 6    25/11/2014   7:00AM                Sabah                      Keningau
# 7    25/11/2014   7:00AM                Sabah                      Sandakan
# 8    25/11/2014   8:00AM               Perlis                        Kangar
# 9    25/11/2014   8:00AM                Kedah                      Langkawi
# 10   25/11/2014   8:00AM                Kedah                    Alor Setar
# 11   25/11/2014   8:00AM                Kedah       Bakar Arang, Sg. Petani
# 12   25/11/2014   8:00AM         Pulau Pinang                           USM
# 13   25/11/2014   8:00AM         Pulau Pinang                         Perai
# 14   25/11/2014   8:00AM         Pulau Pinang        Seberang Jaya 2, Perai
# 15   25/11/2014   8:00AM                Perak             Jalan Tasek, Ipoh
# 16   25/11/2014   8:00AM                Perak         S K Jalan Pegoh, Ipoh
# 17   25/11/2014   8:00AM                Perak        Kg. Air Putih, Taiping
# 18   25/11/2014   8:00AM                Perak                  Seri Manjung
# 19   25/11/2014   8:00AM                Perak                 Tanjung Malim
# 20   25/11/2014   8:00AM             Selangor              Pelabuhan Kelang
# 21   25/11/2014   8:00AM             Selangor                 Petaling Jaya
# 22   25/11/2014   8:00AM             Selangor                       Banting
# 23   25/11/2014   8:00AM             Selangor                     Shah Alam
# 24   25/11/2014   8:00AM             Selangor                Kuala Selangor
# 25   25/11/2014   8:00AM  Wilayah Persekutuan        Batu Muda,Kuala Lumpur
# 26   25/11/2014   8:00AM  Wilayah Persekutuan           Cheras,Kuala Lumpur
# 27   25/11/2014   8:00AM  Wilayah Persekutuan                     Putrajaya
# 28   25/11/2014   8:00AM  Wilayah Persekutuan                        Labuan
# 29   25/11/2014   8:00AM      Negeri Sembilan                         Nilai
# ..          ...      ...                  ...                           ...
# 810  25/11/2014  11:00PM      Negeri Sembilan                      Seremban
# 811  25/11/2014  11:00PM      Negeri Sembilan                  Port Dickson
# 812  25/11/2014  11:00PM               Melaka                  Bukit Rambai
# 813  25/11/2014  11:00PM               Melaka              Bandaraya Melaka
# 814  25/11/2014  11:00PM                Johor                  Pasir Gudang
# 815  25/11/2014  11:00PM                Johor                   Larkin Lama
# 816  25/11/2014  11:00PM                Johor                          Muar
# 817  25/11/2014  11:00PM                Johor                   Kota Tinggi
# 818  25/11/2014  11:00PM             Kelantan                  Tanah Merah
# 819  25/11/2014  11:00PM             Kelantan  SMK Tanjung Chat, Kota Bharu
# 820  25/11/2014  11:00PM           Terengganu                       Kemaman
# 821  25/11/2014  11:00PM           Terengganu                          Paka
# 822  25/11/2014  11:00PM           Terengganu              Kuala Terengganu
# 823  25/11/2014  11:00PM               Pahang                      Jerantut
# 824  25/11/2014  11:00PM               Pahang       Indera Mahkota, Kuantan
# 825  25/11/2014  11:00PM               Pahang           Balok Baru, Kuantan
# 826  25/11/2014  11:00PM              Sarawak                       Kuching
# 827  25/11/2014  11:00PM              Sarawak                          Sibu
# 828  25/11/2014  11:00PM              Sarawak                       Bintulu
# 829  25/11/2014  11:00PM              Sarawak                          Miri
# 830  25/11/2014  11:00PM              Sarawak                      ILP Miri
# 831  25/11/2014  11:00PM              Sarawak                       Sarikei
# 832  25/11/2014  11:00PM              Sarawak                       Limbang
# 833  25/11/2014  11:00PM              Sarawak                     Samarahan
# 834  25/11/2014  11:00PM              Sarawak                      Sri Aman
# 835  25/11/2014  11:00PM              Sarawak                         Kapit
# 836  25/11/2014  11:00PM                Sabah                 Kota Kinabalu
# 837  25/11/2014  11:00PM                Sabah                         Tawau
# 838  25/11/2014  11:00PM                Sabah                      Keningau
# 839  25/11/2014  11:00PM                Sabah                      Sandakan
#
#      API
# 0    27*
# 1    19*
# 2    30*
# 3    19*
# 4    46*
# 5    26*
# 6    34*
# 7    39*
# 8    20*
# 9    25*
# 10   36*
# 11   57*
# 12   51*
# 13   30*
# 14   51*
# 15   38*
# 16   26*
# 17   43*
# 18   27*
# 19   14*
# 20   40*
# 21   31*
# 22   36*
# 23   28*
# 24   19*
# 25   24*
# 26   34*
# 27   31*
# 28   17*
# 29   35*
# ..   ...
# 810  36*
# 811  24*
# 812  46*
# 813  31*
# 814  30*
# 815  30*
# 816  35*
# 817  20*
# 818  31*
# 819  56*
# 820  30*
# 821  23*
# 822  17*
# 823  31*
# 824  22*
# 825  47*
# 826  29*
# 827  19*
# 828  26*
# 829  27*
# 830  18*
# 831  30*
# 832  25*
# 833  19*
# 834  32*
# 835  25*
# 836    #
# 837  24*
# 838  32*
# 839  47*
#
# [840 rows x 5 columns]

# %%
penang=temp[temp["Negeri"] == "Pulau Pinang"]
usm = penang[penang["Kawasan"] == "USM"]
usm
# Out:
#          Tarikh    Waktu        Negeri Kawasan  API
# 12   25/11/2014   8:00AM  Pulau Pinang     USM  51*
# 64   25/11/2014   9:00AM  Pulau Pinang     USM  51*
# 116  25/11/2014  10:00AM  Pulau Pinang     USM  51*
# 168  25/11/2014  11:00AM  Pulau Pinang     USM  52*
# 220  25/11/2014  12:00PM  Pulau Pinang     USM  60c
# 272  25/11/2014   1:00PM  Pulau Pinang     USM  51*
# 324  25/11/2014   2:00PM  Pulau Pinang     USM  51*
# 376  25/11/2014   3:00PM  Pulau Pinang     USM  50*
# 428  25/11/2014   4:00PM  Pulau Pinang     USM  50*
# 480  25/11/2014   5:00PM  Pulau Pinang     USM  49*
# 532  25/11/2014   6:00PM  Pulau Pinang     USM  49*
# 584  25/11/2014   7:00PM  Pulau Pinang     USM  49*
# 636  25/11/2014   8:00PM  Pulau Pinang     USM  49*
# 688  25/11/2014   9:00PM  Pulau Pinang     USM  50*
# 740  25/11/2014  10:00PM  Pulau Pinang     USM  51*
# 792  25/11/2014  11:00PM  Pulau Pinang     USM  51*

# %%
usm["APIVal"] = pandas.Series([int(i[:-1]) for i in usm["API"]], index=usm.index)
usm
# Out:
# /home/sweemeng/anaconda3/envs/codingshophouse2/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#          Tarikh    Waktu        Negeri Kawasan  API  APIVal
# 12   25/11/2014   8:00AM  Pulau Pinang     USM  51*      51
# 64   25/11/2014   9:00AM  Pulau Pinang     USM  51*      51
# 116  25/11/2014  10:00AM  Pulau Pinang     USM  51*      51
# 168  25/11/2014  11:00AM  Pulau Pinang     USM  52*      52
# 220  25/11/2014  12:00PM  Pulau Pinang     USM  60c      60
# 272  25/11/2014   1:00PM  Pulau Pinang     USM  51*      51
# 324  25/11/2014   2:00PM  Pulau Pinang     USM  51*      51
# 376  25/11/2014   3:00PM  Pulau Pinang     USM  50*      50
# 428  25/11/2014   4:00PM  Pulau Pinang     USM  50*      50
# 480  25/11/2014   5:00PM  Pulau Pinang     USM  49*      49
# 532  25/11/2014   6:00PM  Pulau Pinang     USM  49*      49
# 584  25/11/2014   7:00PM  Pulau Pinang     USM  49*      49
# 636  25/11/2014   8:00PM  Pulau Pinang     USM  49*      49
# 688  25/11/2014   9:00PM  Pulau Pinang     USM  50*      50
# 740  25/11/2014  10:00PM  Pulau Pinang     USM  51*      51
# 792  25/11/2014  11:00PM  Pulau Pinang     USM  51*      51

# %%
usm["APIVal"].plot(kind="bar")

# %%
import matplotlib.pyplot as plt
plt.title("API in penang on 25/11/2014")
plt.show()

# %%
usm["APIVal"].plot()
plt.title("API in penang on 25/11/2014")
plt.savefig("API_Penang_2014.png")

# %%
usm["APIVal"].median()
# Out:
# 51.0
